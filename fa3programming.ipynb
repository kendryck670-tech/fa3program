# %% [markdown]
# <a href="https://colab.research.google.com/github/kendryck670-tech/fa3program/blob/main/fa3programming.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#fa3prog1
name = input("Input your name: ")
age = input("Input your age: ")
course = input("Input your course: ")
print("Processing data... please wait.")
time.sleep(3)
print("Name: ", name)
print("Age: ", age)
print("course: ", course)
# Out:
# Input your name: w
# Input your age: w
# Input your course: e
# Processing data, please wait.
# Name:  w
# Age:  w
# course:  e

# %%
#fa3prog2
score = input("Input your score: ")
score = int(score)
if score < 75:
        print("You Failed!")
else:
        print("You Passed!")
# Out:
# Input your score: j
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_4227/663459213.py in <cell line: 0>()
#       1 #fa3prog2
#       2 score = input("Input your score: ")
# ----> 3 score = int(score)
#       4 if score < 75:
#       5         print("You Failed!")
#
# ValueError: invalid literal for int() with base 10: 'j'

# %%
#fa3prog3
name = input("Input your name: ")
score = input("Input your score: ")
print("Name: ", name)
score = int(score)
if score > 89 < 101:
  print("Grade: A")
elif score > 79 < 90:
  print("Grade: B")
elif score > 69 < 80:
  print("Grade: C")
elif score < 70:
  print("Grade: F")
else:
  print("Invalid Score")
# Out:
# Input your name: u
# Input your score: n
# Name:  u
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_4227/4198891560.py in <cell line: 0>()
#       3 score = input("Input your score: ")
#       4 print("Name: ", name)
# ----> 5 score = int(score)
#       6 if score > 89 < 101:
#       7   print("Grade: A")
#
# ValueError: invalid literal for int() with base 10: 'n'
